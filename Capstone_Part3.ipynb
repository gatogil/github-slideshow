# %%
# import libraries
import urllib.request
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import urllib.request

# getting data from internet
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

# using beautiful soup to parse the HTML/XML codes.
soup = BeautifulSoup(raw_wikipedia_page,'xml')
#print(soup.prettify())

# %%
# extracting the raw table inside that webpage
from bs4 import BeautifulSoup

table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %%
#append columns here neighbourhood is not assigned and the borough is the same
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
                
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 181

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
#df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(14)
# Out:
#    Postcode           Borough  \
# 0       M9W         Etobicoke
# 1       M3Y      Not assigned
# 2       M7P      Not assigned
# 3       M5S  Downtown Toronto
# 4       M3J        North York
# 5       M2H        North York
# 6       M3S      Not assigned
# 7       M7G      Not assigned
# 8       M8E      Not assigned
# 9       M9C         Etobicoke
# 10      M7H      Not assigned
# 11      M8K      Not assigned
# 12      M6A        North York
# 13      M1M       Scarborough
#
#                                         Neighbourhood
# 0                                           Northwest
# 1                                        Not assigned
# 2                                        Not assigned
# 3                      Harbord, University of Toronto
# 4                     Northwood Park, York University
# 5                                   Hillcrest Village
# 6                                        Not assigned
# 7                                        Not assigned
# 8                                        Not assigned
# 9   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 10                                       Not assigned
# 11                                       Not assigned
# 12                   Lawrence Heights, Lawrence Manor
# 13    Cliffcrest, Cliffside, Scarborough Village West

# %%
#deleting data where Borough = 'Not Assigned'
df_toronto = df_toronto[df_toronto.Borough != 'Not assigned']

# %%
df_toronto.head(14)
# Out:
#    Postcode           Borough  \
# 0       M9W         Etobicoke
# 3       M5S  Downtown Toronto
# 4       M3J        North York
# 5       M2H        North York
# 9       M9C         Etobicoke
# 12      M6A        North York
# 13      M1M       Scarborough
# 16      M2N        North York
# 17      M9V         Etobicoke
# 20      M2R        North York
# 22      M1J       Scarborough
# 23      M4V   Central Toronto
# 24      M1L       Scarborough
# 25      M1K       Scarborough
#
#                                         Neighbourhood
# 0                                           Northwest
# 3                      Harbord, University of Toronto
# 4                     Northwood Park, York University
# 5                                   Hillcrest Village
# 9   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 12                   Lawrence Heights, Lawrence Manor
# 13    Cliffcrest, Cliffside, Scarborough Village West
# 16                                   Willowdale South
# 17  Albion Gardens, Beaumond Heights, Humbergate, ...
# 20                                    Willowdale West
# 22                                Scarborough Village
# 23  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 24                    Clairlea, Golden Mile, Oakridge
# 25        East Birchmount Park, Ionview, Kennedy Park

# %%
#import coordinates data
path='Geospatial_Coordinates.csv'

df = pd.read_csv(path)

# %%
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#rename postal code feild to match df_toronto df
df = df.rename(index=str, columns={"Postal Code": "Postcode"})

# %%
df.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
#merging two dataframes on postcode into a new data
df_ton = pd.merge(left=df_toronto, right=df, on="Postcode", how="left")

# %%
df_ton.head(200)
# Out:
#     Postcode           Borough  \
# 0        M9W         Etobicoke
# 1        M5S  Downtown Toronto
# 2        M3J        North York
# 3        M2H        North York
# 4        M9C         Etobicoke
# 5        M6A        North York
# 6        M1M       Scarborough
# 7        M2N        North York
# 8        M9V         Etobicoke
# 9        M2R        North York
# 10       M1J       Scarborough
# 11       M4V   Central Toronto
# 12       M1L       Scarborough
# 13       M1K       Scarborough
# 14       M4C         East York
# 15       M6R      West Toronto
# 16       M5R   Central Toronto
# 17       M5P   Central Toronto
# 18       M5E  Downtown Toronto
# 19       M4R   Central Toronto
# 20       M5C  Downtown Toronto
# 21       M3B        North York
# 22       M4J         East York
# 23       M5V  Downtown Toronto
# 24       M1B       Scarborough
# 25       M9N              York
# 26       M2J        North York
# 27       M4S   Central Toronto
# 28       M1T       Scarborough
# 29       M1W       Scarborough
# ..       ...               ...
# 74       M4E      East Toronto
# 75       M2M        North York
# 76       M8V         Etobicoke
# 77       M1S       Scarborough
# 78       M6C              York
# 79       M5W  Downtown Toronto
# 80       M7R       Mississauga
# 81       M5J  Downtown Toronto
# 82       M5T  Downtown Toronto
# 83       M4X  Downtown Toronto
# 84       M5X  Downtown Toronto
# 85       M4B         East York
# 86       M2L        North York
# 87       M6K      West Toronto
# 88       M1C       Scarborough
# 89       M6P      West Toronto
# 90       M8W         Etobicoke
# 91       M1V       Scarborough
# 92       M9P         Etobicoke
# 93       M3C        North York
# 94       M6J      West Toronto
# 95       M5N   Central Toronto
# 96       M6G  Downtown Toronto
# 97       M6B        North York
# 98       M6E              York
# 99       M1E       Scarborough
# 100      M5G  Downtown Toronto
# 101      M5H  Downtown Toronto
# 102      M1P       Scarborough
# 103       -1                -1
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Northwest  43.706748 -79.594054
# 1                       Harbord, University of Toronto  43.662696 -79.400049
# 2                      Northwood Park, York University  43.767980 -79.487262
# 3                                    Hillcrest Village  43.803762 -79.363452
# 4    Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 5                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 6      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 7                                     Willowdale South  43.770120 -79.408493
# 8    Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 9                                      Willowdale West  43.782736 -79.442259
# 10                                 Scarborough Village  43.744734 -79.239476
# 11   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 12                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 13         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                              Parkdale, Roncesvalles  43.648960 -79.456325
# 16                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 17                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 18                                         Berczy Park  43.644771 -79.373306
# 19                                  North Toronto West  43.715383 -79.405678
# 20                                      St. James Town  43.651494 -79.375418
# 21                                     Don Mills North  43.745906 -79.352188
# 22                                        East Toronto  43.685347 -79.338106
# 23   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 24                                      Rouge, Malvern  43.806686 -79.194353
# 25                                              Weston  43.706876 -79.518188
# 26                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 27                                          Davisville  43.704324 -79.388790
# 28             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 29                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# ..                                                 ...        ...        ...
# 74                                         The Beaches  43.676357 -79.293031
# 75                             Newtonbrook, Willowdale  43.789053 -79.408493
# 76        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 77                                           Agincourt  43.794200 -79.262029
# 78                                  Humewood-Cedarvale  43.693781 -79.428191
# 79                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 80               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 81   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 82           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 83                         Cabbagetown, St. James Town  43.667967 -79.367675
# 84              First Canadian Place, Underground city  43.648429 -79.382280
# 85                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 86                            Silver Hills, York Mills  43.757490 -79.374714
# 87        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 88              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 89                       High Park, The Junction South  43.661608 -79.464763
# 90                              Alderwood, Long Branch  43.602414 -79.543484
# 91   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 92                                           Westmount  43.696319 -79.532242
# 93                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 94                            Little Portugal, Trinity  43.647927 -79.419750
# 95                                            Roselawn  43.711695 -79.416936
# 96                                            Christie  43.669542 -79.422564
# 97                                           Glencairn  43.709577 -79.445073
# 98                                 Caledonia-Fairbanks  43.689026 -79.453512
# 99                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 100                                 Central Bay Street  43.657952 -79.387383
# 101                           Adelaide, King, Richmond  43.650571 -79.384568
# 102  Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 103                                                 -1        NaN        NaN
#
# [104 rows x 5 columns]

# %%
df_ton.dtypes
# Out:
# Postcode          object
# Borough           object
# Neighbourhood     object
# Latitude         float64
# Longitude        float64
# dtype: object

# %%
#there are some NaN records for some reason, so must delete
#df_ton = df_ton[df_ton.Postcode != 'NaN']

df_ton = df_ton[:-1]

# %%
df_ton.head(104)
# Out:
#     Postcode           Borough  \
# 0        M9W         Etobicoke
# 1        M5S  Downtown Toronto
# 2        M3J        North York
# 3        M2H        North York
# 4        M9C         Etobicoke
# 5        M6A        North York
# 6        M1M       Scarborough
# 7        M2N        North York
# 8        M9V         Etobicoke
# 9        M2R        North York
# 10       M1J       Scarborough
# 11       M4V   Central Toronto
# 12       M1L       Scarborough
# 13       M1K       Scarborough
# 14       M4C         East York
# 15       M6R      West Toronto
# 16       M5R   Central Toronto
# 17       M5P   Central Toronto
# 18       M5E  Downtown Toronto
# 19       M4R   Central Toronto
# 20       M5C  Downtown Toronto
# 21       M3B        North York
# 22       M4J         East York
# 23       M5V  Downtown Toronto
# 24       M1B       Scarborough
# 25       M9N              York
# 26       M2J        North York
# 27       M4S   Central Toronto
# 28       M1T       Scarborough
# 29       M1W       Scarborough
# ..       ...               ...
# 73       M4M      East Toronto
# 74       M4E      East Toronto
# 75       M2M        North York
# 76       M8V         Etobicoke
# 77       M1S       Scarborough
# 78       M6C              York
# 79       M5W  Downtown Toronto
# 80       M7R       Mississauga
# 81       M5J  Downtown Toronto
# 82       M5T  Downtown Toronto
# 83       M4X  Downtown Toronto
# 84       M5X  Downtown Toronto
# 85       M4B         East York
# 86       M2L        North York
# 87       M6K      West Toronto
# 88       M1C       Scarborough
# 89       M6P      West Toronto
# 90       M8W         Etobicoke
# 91       M1V       Scarborough
# 92       M9P         Etobicoke
# 93       M3C        North York
# 94       M6J      West Toronto
# 95       M5N   Central Toronto
# 96       M6G  Downtown Toronto
# 97       M6B        North York
# 98       M6E              York
# 99       M1E       Scarborough
# 100      M5G  Downtown Toronto
# 101      M5H  Downtown Toronto
# 102      M1P       Scarborough
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Northwest  43.706748 -79.594054
# 1                       Harbord, University of Toronto  43.662696 -79.400049
# 2                      Northwood Park, York University  43.767980 -79.487262
# 3                                    Hillcrest Village  43.803762 -79.363452
# 4    Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 5                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 6      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 7                                     Willowdale South  43.770120 -79.408493
# 8    Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 9                                      Willowdale West  43.782736 -79.442259
# 10                                 Scarborough Village  43.744734 -79.239476
# 11   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 12                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 13         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                              Parkdale, Roncesvalles  43.648960 -79.456325
# 16                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 17                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 18                                         Berczy Park  43.644771 -79.373306
# 19                                  North Toronto West  43.715383 -79.405678
# 20                                      St. James Town  43.651494 -79.375418
# 21                                     Don Mills North  43.745906 -79.352188
# 22                                        East Toronto  43.685347 -79.338106
# 23   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 24                                      Rouge, Malvern  43.806686 -79.194353
# 25                                              Weston  43.706876 -79.518188
# 26                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 27                                          Davisville  43.704324 -79.388790
# 28             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 29                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# ..                                                 ...        ...        ...
# 73                                     Studio District  43.659526 -79.340923
# 74                                         The Beaches  43.676357 -79.293031
# 75                             Newtonbrook, Willowdale  43.789053 -79.408493
# 76        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 77                                           Agincourt  43.794200 -79.262029
# 78                                  Humewood-Cedarvale  43.693781 -79.428191
# 79                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 80               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 81   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 82           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 83                         Cabbagetown, St. James Town  43.667967 -79.367675
# 84              First Canadian Place, Underground city  43.648429 -79.382280
# 85                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 86                            Silver Hills, York Mills  43.757490 -79.374714
# 87        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 88              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 89                       High Park, The Junction South  43.661608 -79.464763
# 90                              Alderwood, Long Branch  43.602414 -79.543484
# 91   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 92                                           Westmount  43.696319 -79.532242
# 93                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 94                            Little Portugal, Trinity  43.647927 -79.419750
# 95                                            Roselawn  43.711695 -79.416936
# 96                                            Christie  43.669542 -79.422564
# 97                                           Glencairn  43.709577 -79.445073
# 98                                 Caledonia-Fairbanks  43.689026 -79.453512
# 99                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 100                                 Central Bay Street  43.657952 -79.387383
# 101                           Adelaide, King, Richmond  43.650571 -79.384568
# 102  Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
#
# [103 rows x 5 columns]

# %%
#importing folium library
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-2.3.0               |        py36_1001         533 KB  conda-forge
#     pandas-0.23.4              |   py36hf8a1672_0        27.8 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        28.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.3.0-py36_1001       conda-forge
#     branca:  0.3.1-py_0            conda-forge
#     folium:  0.5.0-py_0            conda-forge
#     vincent: 0.4.4-py_1            conda-forge
#
# The following packages will be UPDATED:
#
#     pandas:  0.23.4-py37h04863e7_0             --> 0.23.4-py36hf8a1672_0 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-2.3.0         | 533 KB    | ##################################### | 100%
# pandas-0.23.4        | 27.8 MB   | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# create map of Toronto using latitude and longitude values
toronto_latitude = 43.6532; toronto_longitude = -79.3832
map_toronto = folium.Map(location = [toronto_latitude, toronto_longitude], zoom_start = 10.7)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_ton['Latitude'], df_ton['Longitude'], df_ton['Borough'], df_ton['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
